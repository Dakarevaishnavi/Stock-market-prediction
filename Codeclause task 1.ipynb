# %% [markdown]
# ## STOCK MARKET PREDICTION

# %% [raw]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv('C:\\Users\\VAISHNAVI DAKARE\\Downloads\\Tesla.csv - Tesla.csv.csv')
df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# ...

# %%
df.shape
# Out:
# (1692, 7)

# %%
df.info
# Out:
# <bound method DataFrame.info of            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
round(df.isnull().sum()/len(df.index), 2)*100
# Out:
# Date         0.0
# Open         0.0
# High         0.0
# Low          0.0
# Close        0.0
# Volume       0.0
# Adj Close    0.0
# dtype: float64

# %%
df[df['Date'] == 'BAUTO'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       0 non-null      object
#  1   Open       0 non-null      float64
#  2   High       0 non-null      float64
#  3   Low        0 non-null      float64
#  4   Close      0 non-null      float64
#  5   Volume     0 non-null      int64
#  6   Adj Close  0 non-null      float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 0.0+ bytes

# %%
df['Open'].value_counts() \
  .head(20) \
  .plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Volume'].value_counts() \
  .head(30) \
  .plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Volume'].value_counts() \
  .head(15) \
  .plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Volume'>

# %%
df['Volume'].value_counts() \
  .head(10) \
  .plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Volume'].value_counts() \
  .head(15) \


sns.heatmap(df, cmap="Blues")
plt.show()

# %%
df = pd.DataFrame(np.random.random((11,11)), columns=["title","director","country","release_year","rating","show_id","type","cast","date_added","duration","description"])
sns.heatmap(df, cmap="BuPu")
plt.show()

sns.heatmap(df,cmap="Greens")
plt.show()

# %%
plt.figure(figsize=(12, 12))

columns = [str(c) for c in df.columns]

for i, c in enumerate(columns):
    pyplot.subplot(len(columns), 1, i+1)
    pyplot.plot(df[c])
    pyplot.title(c, y=0.5, loc='right')

plt.show()

# %%
norm_df = df.copy()
norm_df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# ...

# %%
norm_target_df = df[['Close']].copy()
norm_target_df
# Out:
#            Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# 3      19.200001
# 4      16.110001
# ...          ...
# 1687  246.169998
# 1688  258.000000
# 1689  255.729996
# 1690  262.049988
# 1691  261.500000
#
# [1692 rows x 1 columns]

# %%
#Dataframe to numpy array
norm_X = norm_df.values
norm_X
# Out:
# array([['6/29/2010', 19.0, 25.0, ..., 23.889999, 18766300, 23.889999],
#        ['6/30/2010', 25.790001, 30.42, ..., 23.83, 17187100, 23.83],
#        ['7/1/2010', 25.0, 25.92, ..., 21.959999, 8218800, 21.959999],
#        ...,
#        ['3/15/2017', 257.0, 261.0, ..., 255.729996, 4816600, 255.729996],
#        ['3/16/2017', 262.399994, 265.75, ..., 262.049988, 7100400,
#         262.049988],
#        ['3/17/2017', 264.0, 265.329987, ..., 261.5, 6475900, 261.5]],
#       dtype=object)

# %%
norm_y = norm_target_df.values
norm_y
# Out:
# array([[ 23.889999],
#        [ 23.83    ],
#        [ 21.959999],
#        ...,
#        [255.729996],
#        [262.049988],
#        [261.5     ]])

# %%
df.plot(subplots=True,figsize=(5,5));

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
